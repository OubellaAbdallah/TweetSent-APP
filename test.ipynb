# %%
from twikit import Client
client = Client('en-US')
client.load_cookies('cookies.json')
USERNAME = 'AitLmehdi15670 '
EMAIL = 'aitoubellalmehdi@gmail.com'
PASSWORD = 'oubellaabdellah@17082003'

await client.login(
    auth_info_1=USERNAME,
    auth_info_2=EMAIL,
    password=PASSWORD,
)


client.save_cookies("cookies.json")

# %%
tweets = await client.search_tweet('usa', 'Latest',5)

for i,tweet in enumerate(tweets):
    print(
       i,' : ', tweet.text
    )
# Out:
# 0  :  @_wake_up_USA YES
# 1  :  @SprinterObserve that Iran produces its nuclear bomb. that all other countries have the same right as the USA, France, Italy, Russia and Israel to manufacture nuclear bombs.
# when everyone has bombs, invasions and robberies will end.
# 2  :  @BernivargasO Brooo a alegria. Felicidades!
#
# Yo no soy quien para dar ese tipo de consejos. Pero mi familia AMA USA. Y estoy bastante seguro q no hubiese conseguido lo q conseguí en el tiempo que lo hice si viviera en otro lado.
# 3  :  ده معرفش مؤهلاته ايه بس هو واخد دكتوراه فى ضربه الجزاء🤣
#
# امريكا هى من انقذت البطوله و نظمتها.
# لولا امريكا مكنتش هتشوف الاهلى الفاسد بتاعك.
#
# انت روحت امريكا قاعت شهر على حساب تركى ومش عاجبك امريكا؟!
#
# احنا 🇺🇸مؤهلين نعمل اى حاجه و فى اى وقت!
#
# USA is the best, F*uk all the rest
# 4  :  @T_Kai_CoD うおおおアツいですそれは

# %%
client.save_cookies("cookies.json")
